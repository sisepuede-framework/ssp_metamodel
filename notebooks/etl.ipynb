# %%
import pandas as pd
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
ROOT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
DATA_DIR_PATH = os.path.join(ROOT_DIR_PATH, "data")
MAPPING_DIR_PATH = os.path.join(DATA_DIR_PATH, "mapping")
PREDICTORS_DIR_PATH = os.path.join(DATA_DIR_PATH, "predictors")
SSP_DIR_PATH = os.path.join(DATA_DIR_PATH, "ssp")
SIMULATION_DIR_PATH = os.path.join(SSP_DIR_PATH, "sisepuede_run_2025-01-14T17;04;06.975301_output_database")
TRAINING_DIR_PATH = os.path.join(DATA_DIR_PATH, "training")

# %%
lhc_trials_df = pd.read_csv(os.path.join(PREDICTORS_DIR_PATH, "lhs_sample_group_experiments.csv"))
lhc_trials_df
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.952436  0.360397  0.202990  0.995748  0.369859  0.919920  0.478450
# 1    0.304955  0.204875  0.540658  0.800192  0.206396  0.777352  0.805727
# 2    0.609262  0.366443  0.601808  0.916668  0.386475  0.181162  0.138910
# 3    0.815313  0.487444  0.323954  0.634299  0.064625  0.926815  0.633805
# 4    0.973878  0.842718  0.884382  0.483039  0.455502  0.003343  0.571994
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.218189  0.886941  0.569155  0.107766  0.955775  0.380014  0.569711
# 996  0.510025  0.235856  0.847465  0.138888  0.182086  0.453749  0.242018
# 997  0.276479  0.612911  0.642697  0.952037  0.176638  0.411246  0.169671
# 998  0.600573  0.553323  0.306380  0.464389  0.834916  0.786519  0.717580
# 999  0.164542  0.057579  0.648085  0.210240  0.441924  0.364614  0.031031
#
#             8         9        10  ...      1472      1473      1474  \
# 0    0.445798  0.490988  0.510280  ...  0.985425  0.482783  0.183188
# 1    0.536048  0.779857  0.623335  ...  0.437877  0.149747  0.308130
# 2    0.768925  0.884425  0.232722  ...  0.360238  0.348950  0.165501
# 3    0.439346  0.027114  0.532020  ...  0.060470  0.660562  0.621883
# 4    0.108021  0.346714  0.892123  ...  0.910718  0.621574  0.244454
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.312233  0.791412  0.300450  ...  0.669261  0.883331  0.431040
# 996  0.215693  0.657012  0.808412  ...  0.538035  0.037013  0.528031
# 997  0.694365  0.606286  0.678398  ...  0.262631  0.657597  0.243538
# 998  0.168263  0.009808  0.855097  ...  0.069343  0.293393  0.632635
# 999  0.873487  0.951080  0.509441  ...  0.486452  0.115074  0.989445
#
#          1475      1476      1477      1478      1480      1481  future_id
# 0    0.364889  0.005297  0.223598  0.927810  0.036368  0.933822          1
# 1    0.780839  0.784662  0.742266  0.147130  0.081654  0.491202          2
# 2    0.813845  0.950005  0.342632  0.053104  0.316417  0.173655          3
# 3    0.911838  0.030974  0.912003  0.150989  0.246583  0.353195          4
# 4    0.927056  0.561529  0.611280  0.552761  0.125694  0.147930          5
# ..        ...       ...       ...       ...       ...       ...        ...
# 995  0.045121  0.790492  0.081530  0.351688  0.746613  0.853002        996
# 996  0.079728  0.918024  0.653280  0.161674  0.033243  0.257661        997
# 997  0.603350  0.377625  0.316224  0.615736  0.996441  0.704642        998
# 998  0.168413  0.611178  0.295950  0.813797  0.934377  0.473035        999
# 999  0.965431  0.352193  0.278569  0.164544  0.144563  0.306248       1000
#
# [1000 rows x 85 columns]

# %%
la_emissions_df = pd.read_csv(os.path.join(SIMULATION_DIR_PATH, "MODEL_OUTPUT.csv"))
la_emissions_df
# Out:
#        primary_id     region  time_period  area_agrc_crops_bevs_and_spices  \
# 0          275275  louisiana            0                              0.0
# 1          275275  louisiana            1                              0.0
# 2          275275  louisiana            2                              0.0
# 3          275275  louisiana            3                              0.0
# 4          275275  louisiana            4                              0.0
# ...           ...        ...          ...                              ...
# 36031      276275  louisiana           31                              0.0
# 36032      276275  louisiana           32                              0.0
# 36033      276275  louisiana           33                              0.0
# 36034      276275  louisiana           34                              0.0
# 36035      276275  louisiana           35                              0.0
#
#        area_agrc_crops_cereals  area_agrc_crops_fibers  \
# 0                367983.831774            68239.857458
# 1                362385.636787            67201.713944
# 2                361096.126663            66962.583908
# 3                359935.747562            66747.400257
# 4                358773.521179            66531.874041
# ...                        ...                     ...
# 36031            309402.632008            67494.007968
# 36032            309172.389911            68774.060665
# 36033            308983.403716            70116.106905
# 36034            308833.414335            71512.549952
# 36035            308715.398813            72954.834981
#
#        area_agrc_crops_fruits  \
# 0                   80.234375
# 1                   79.013757
# 2                   78.732596
# 3                   78.479589
# 4                   78.226180
# ...                       ...
# 36031               99.280790
# 36032              102.272019
# 36033              105.313909
# 36034              108.393442
# 36035              111.497279
#
#        area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                         79198.541655           6714.566582
# 1                                         77993.681983           6612.416842
# 2                                         77716.149895           6588.887271
# 3                                         77466.409758           6567.713942
# 4                                         77216.272044           6546.506906
# ...                                                ...                   ...
# 36031                                     89132.167800          16695.284559
# 36032                                     91149.219633          18708.483406
# 36033                                     93186.116688          21109.791025
# 36034                                     95232.747284          24019.931656
# 36035                                     97278.672613          27620.872881
#
#        area_agrc_crops_other_annual  ...  yield_agrc_fruits_tonne  \
# 0                      1.154590e+06  ...              1607.703461
# 1                      1.137025e+06  ...              1618.201188
# 2                      1.132979e+06  ...              1574.244188
# 3                      1.129338e+06  ...              1487.104127
# 4                      1.125692e+06  ...              1583.188921
# ...                             ...  ...                      ...
# 36031                  1.161004e+06  ...              1449.350481
# 36032                  1.177036e+06  ...              1477.427300
# 36033                  1.193151e+06  ...              1505.572198
# 36034                  1.209256e+06  ...              1533.599093
# 36035                  1.225251e+06  ...              1561.352004
#
#        yield_agrc_herbs_and_other_perennial_crops_tonne  \
# 0                                         955073.693482
# 1                                         978025.173334
# 2                                         945124.232643
# 3                                         951997.620585
# 4                                         952671.199593
# ...                                                 ...
# 36031                                     871948.732854
# 36032                                     885367.523944
# 36033                                     898808.002401
# 36034                                     912175.594875
# 36035                                     925391.026439
#
#        yield_agrc_nuts_tonne  yield_agrc_other_annual_tonne  \
# 0               19786.484805                   7.132381e+06
# 1               22849.096189                   8.147695e+06
# 2               20042.187116                   1.259799e+07
# 3               22167.895406                   6.139224e+06
# 4               19588.348855                   6.953864e+06
# ...                      ...                            ...
# 36031           12592.990056                   7.021991e+06
# 36032           12723.047466                   7.109925e+06
# 36033           12811.278216                   7.198400e+06
# 36034           12844.529332                   7.286867e+06
# 36035           12806.362698                   7.374855e+06
#
#        yield_agrc_other_woody_perennial_tonne  yield_agrc_pulses_tonne  \
# 0                                         0.0               985.642069
# 1                                         0.0              1148.204785
# 2                                         0.0              1389.455885
# 3                                         0.0              1457.885138
# 4                                         0.0              1125.040763
# ...                                       ...                      ...
# 36031                                     0.0              1055.062331
# 36032                                     0.0              1059.561793
# 36033                                     0.0              1064.598028
# 36034                                     0.0              1070.123263
# 36035                                     0.0              1076.088767
#
#        yield_agrc_rice_tonne  yield_agrc_sugar_cane_tonne  \
# 0               2.422231e+06                 2.104457e+07
# 1               2.272766e+06                 2.016430e+07
# 2               2.285081e+06                 2.525521e+07
# 3               2.426876e+06                 2.538268e+07
# 4               2.155513e+06                 2.356779e+07
# ...                      ...                          ...
# 36031           2.276019e+06                 2.403699e+07
# 36032           2.296005e+06                 2.393306e+07
# 36033           2.315909e+06                 2.383202e+07
# 36034           2.335624e+06                 2.373561e+07
# 36035           2.355067e+06                 2.364535e+07
#
#        yield_agrc_tubers_tonne  yield_agrc_vegetables_and_vines_tonne
# 0                166526.651285                             147.841681
# 1                170339.476720                             150.359797
# 2                170252.877121                             144.566821
# 3                162040.494052                             147.924261
# 4                166703.308298                             163.887648
# ...                        ...                                    ...
# 36031            196573.614611                             166.806631
# 36032            197056.903265                             167.693033
# 36033            197544.003011                             168.591509
# 36034            198045.569544                             169.504094
# 36035            198571.034958                             170.432604
#
# [36036 rows x 1453 columns]

# %% [markdown]
# ## Transform emissions time series data in target variables

# %%
subsector_totals_cols = [col for col in la_emissions_df.columns if "emission_co2e_subsector_total" in col]
subsector_totals_cols
# Out:
# ['emission_co2e_subsector_total_agrc',
#  'emission_co2e_subsector_total_ccsq',
#  'emission_co2e_subsector_total_entc',
#  'emission_co2e_subsector_total_fgtv',
#  'emission_co2e_subsector_total_frst',
#  'emission_co2e_subsector_total_inen',
#  'emission_co2e_subsector_total_ippu',
#  'emission_co2e_subsector_total_lndu',
#  'emission_co2e_subsector_total_lsmm',
#  'emission_co2e_subsector_total_lvst',
#  'emission_co2e_subsector_total_scoe',
#  'emission_co2e_subsector_total_soil',
#  'emission_co2e_subsector_total_trns',
#  'emission_co2e_subsector_total_trww',
#  'emission_co2e_subsector_total_waso']

# %%
# Calculate total_emissions
la_emissions_df["total_emissions"] = la_emissions_df[subsector_totals_cols].sum(axis=1)

cols_to_keep = ["primary_id", "time_period", "total_emissions"] + subsector_totals_cols

la_emissions_df = la_emissions_df[cols_to_keep]

la_emissions_df
# Out:
#        primary_id  time_period  total_emissions  \
# 0          275275            0       286.240266
# 1          275275            1       309.612427
# 2          275275            2       255.419631
# 3          275275            3       346.415753
# 4          275275            4       314.404711
# ...           ...          ...              ...
# 36031      276275           31       143.883905
# 36032      276275           32       139.413018
# 36033      276275           33       134.994698
# 36034      276275           34       130.557026
# 36035      276275           35       126.237780
#
#        emission_co2e_subsector_total_agrc  emission_co2e_subsector_total_ccsq  \
# 0                                1.584478                            0.000000
# 1                                1.573848                            0.000000
# 2                                1.667754                            0.000000
# 3                                1.557793                            0.000000
# 4                                1.538893                            0.000000
# ...                                   ...                                 ...
# 36031                            1.596347                          -12.973105
# 36032                            1.613380                          -13.655900
# 36033                            1.630549                          -14.338695
# 36034                            1.647803                          -15.021490
# 36035                            1.665097                          -15.704285
#
#        emission_co2e_subsector_total_entc  emission_co2e_subsector_total_fgtv  \
# 0                               87.202869                           13.785113
# 1                               88.990055                           13.574044
# 2                               85.401680                           12.342081
# 3                               91.676280                           13.536455
# 4                               83.599591                           12.560791
# ...                                   ...                                 ...
# 36031                           47.564903                            4.162504
# 36032                           47.509988                            3.951722
# 36033                           47.481051                            3.737744
# 36034                           47.444460                            3.516989
# 36035                           47.403051                            3.288036
#
#        emission_co2e_subsector_total_frst  emission_co2e_subsector_total_inen  \
# 0                              -25.538740                           34.955562
# 1                              -26.918532                           35.550361
# 2                              -20.181094                           26.431299
# 3                              -13.789889                           47.900892
# 4                              -39.346740                           48.043708
# ...                                   ...                                 ...
# 36031                          -27.029063                           12.335944
# 36032                          -27.324700                           11.794201
# 36033                          -27.620392                           11.274044
# 36034                          -27.915374                           10.774941
# 36035                          -28.209338                           10.493363
#
#        emission_co2e_subsector_total_ippu  emission_co2e_subsector_total_lndu  \
# 0                               92.323613                            9.987402
# 1                              117.400000                            9.974551
# 2                               70.076960                            9.718344
# 3                              122.294593                           10.207034
# 4                              124.008505                           10.062773
# ...                                   ...                                 ...
# 36031                           49.094989                            7.600756
# 36032                           46.812204                            7.624813
# 36033                           44.500519                            7.648067
# 36034                           42.151681                            7.671965
# 36035                           39.756759                            7.646306
#
#        emission_co2e_subsector_total_lsmm  emission_co2e_subsector_total_lvst  \
# 0                                0.284571                            1.240654
# 1                                0.282116                            1.231179
# 2                                0.282270                            1.226150
# 3                                0.283177                            1.221255
# 4                                0.284135                            1.218990
# ...                                   ...                                 ...
# 36031                            0.266807                            1.129693
# 36032                            0.264323                            1.121804
# 36033                            0.261796                            1.114018
# 36034                            0.259227                            1.106348
# 36035                            0.256538                            1.098241
#
#        emission_co2e_subsector_total_scoe  emission_co2e_subsector_total_soil  \
# 0                                5.408010                           18.198756
# 1                                4.777919                           18.470387
# 2                                4.587107                           18.501348
# 3                                4.909771                           18.782501
# 4                                4.955352                           18.832322
# ...                                   ...                                 ...
# 36031                            4.151388                           13.988376
# 36032                            4.097062                           13.970345
# 36033                            4.042772                           13.978804
# 36034                            3.988216                           13.988979
# 36035                            3.933127                           14.004328
#
#        emission_co2e_subsector_total_trns  emission_co2e_subsector_total_trww  \
# 0                               43.813502                            1.194832
# 1                               41.755424                            1.181568
# 2                               42.378982                            1.193562
# 3                               44.782787                            1.215421
# 4                               45.549952                            1.234366
# ...                                   ...                                 ...
# 36031                           39.020458                            1.515877
# 36032                           38.716472                            1.512743
# 36033                           38.427685                            1.508281
# 36034                           38.151255                            1.502419
# 36035                           37.883587                            1.495070
#
#        emission_co2e_subsector_total_waso
# 0                                1.799645
# 1                                1.769505
# 2                                1.793187
# 3                                1.837684
# 4                                1.862073
# ...                                   ...
# 36031                            1.458031
# 36032                            1.404560
# 36033                            1.348455
# 36034                            1.289608
# 36035                            1.227898
#
# [36036 rows x 18 columns]

# %%
# Filter out rows with time_period <= 30
la_emissions_df = la_emissions_df[la_emissions_df["time_period"] > 30]
la_emissions_df.head(7)
# Out:
#     primary_id  time_period  total_emissions  \
# 31      275275           31        41.665117
# 32      275275           32        34.880394
# 33      275275           33        28.168149
# 34      275275           34        21.138362
# 35      275275           35        14.413315
# 67      275276           31       143.777093
# 68      275276           32       138.867103
#
#     emission_co2e_subsector_total_agrc  emission_co2e_subsector_total_ccsq  \
# 31                            1.460253                          -25.682628
# 32                            1.457065                          -27.034345
# 33                            1.453646                          -28.386062
# 34                            1.450095                          -29.737779
# 35                            1.446492                          -31.089497
# 67                            1.584180                          -25.580624
# 68                            1.598803                          -26.926973
#
#     emission_co2e_subsector_total_entc  emission_co2e_subsector_total_fgtv  \
# 31                           15.317286                            1.212687
# 32                           15.403158                            1.111842
# 33                           15.490064                            1.010105
# 34                           15.249905                            0.862243
# 35                           15.227005                            0.748293
# 67                           66.071374                           10.257866
# 68                           66.440282                           10.198394
#
#     emission_co2e_subsector_total_frst  emission_co2e_subsector_total_inen  \
# 31                          -20.495922                            2.128745
# 32                          -20.646063                            1.648109
# 33                          -20.820842                            1.213478
# 34                          -21.015871                            0.821065
# 35                          -21.224761                            0.467359
# 67                          -18.478956                            7.536667
# 68                          -18.320145                            6.970375
#
#     emission_co2e_subsector_total_ippu  emission_co2e_subsector_total_lndu  \
# 31                           27.090024                            5.243563
# 32                           24.078243                            5.212332
# 33                           21.083855                            5.182569
# 34                           18.101447                            5.153970
# 35                           15.125732                            5.127605
# 67                           38.857826                            9.881355
# 68                           36.451113                            9.886850
#
#     emission_co2e_subsector_total_lsmm  emission_co2e_subsector_total_lvst  \
# 31                            0.138398                            0.720310
# 32                            0.127932                            0.684143
# 33                            0.117441                            0.647237
# 34                            0.106999                            0.609900
# 35                            0.096632                            0.572016
# 67                            0.195127                            0.761457
# 68                            0.188235                            0.733936
#
#     emission_co2e_subsector_total_scoe  emission_co2e_subsector_total_soil  \
# 31                            0.700690                           12.639186
# 32                            0.515803                           12.410605
# 33                            0.337226                           12.200026
# 34                            0.165190                           11.999088
# 35                            0.000000                           11.810748
# 67                            1.923244                           17.718429
# 68                            1.774252                           17.798955
#
#     emission_co2e_subsector_total_trns  emission_co2e_subsector_total_trww  \
# 31                           19.285611                            0.849438
# 32                           18.152515                            0.784585
# 33                           17.036721                            0.714894
# 34                           15.934656                            0.640156
# 35                           14.842692                            0.560147
# 67                           29.622057                            1.046626
# 68                           28.671540                            1.007325
#
#     emission_co2e_subsector_total_waso
# 31                            1.057476
# 32                            0.974471
# 33                            0.887790
# 34                            0.797297
# 35                            0.702855
# 67                            2.380465
# 68                            2.394161

# %%
# aggregate data by primary_id and region by summing the emissions
la_emissions_df_agg = la_emissions_df.groupby(["primary_id"]).sum().reset_index()

# Rename the total_emissions column to total_emissions_last_five_years
la_emissions_df_agg.rename(columns={"total_emissions": "total_emissions_last_five_years"}, inplace=True)

# Rename all the cols that start with emission_co2e_subsector_total to have a suffix of _last_five_years
for col in subsector_totals_cols:
    new_col_name = col.replace("emission_co2e_subsector_total", "emission_co2e_subsector_total_last_five_years")
    la_emissions_df_agg.rename(columns={col: new_col_name}, inplace=True)

la_emissions_df_agg
# Out:
#       primary_id  time_period  total_emissions_last_five_years  \
# 0         275275          165                       140.265338
# 1         275276          165                       670.507643
# 2         275277          165                       604.450538
# 3         275278          165                       475.708631
# 4         275279          165                       758.004335
# ...          ...          ...                              ...
# 996       276271          165                       623.338641
# 997       276272          165                       747.358673
# 998       276273          165                       634.154137
# 999       276274          165                       915.717778
# 1000      276275          165                       675.086427
#
#       emission_co2e_subsector_total_last_five_years_agrc  \
# 0                                              7.267550
# 1                                              8.061759
# 2                                              7.858164
# 3                                              8.307819
# 4                                              8.405054
# ...                                                 ...
# 996                                            7.691330
# 997                                            8.862801
# 998                                            6.485737
# 999                                            6.846038
# 1000                                           8.153176
#
#       emission_co2e_subsector_total_last_five_years_ccsq  \
# 0                                           -141.930311
# 1                                           -141.366606
# 2                                            -14.533055
# 3                                           -129.785123
# 4                                            -71.502824
# ...                                                 ...
# 996                                          -71.971267
# 997                                         -127.413593
# 998                                         -123.391600
# 999                                          -37.048767
# 1000                                         -71.693475
#
#       emission_co2e_subsector_total_last_five_years_entc  \
# 0                                             76.687418
# 1                                            334.273021
# 2                                            191.759751
# 3                                            117.203083
# 4                                            264.993930
# ...                                                 ...
# 996                                          192.425095
# 997                                          272.882069
# 998                                          291.514723
# 999                                          205.389288
# 1000                                         237.403454
#
#       emission_co2e_subsector_total_last_five_years_fgtv  \
# 0                                              4.945170
# 1                                             50.634794
# 2                                             22.453442
# 3                                             12.867610
# 4                                             34.352460
# ...                                                 ...
# 996                                           32.765217
# 997                                           52.957656
# 998                                           34.935666
# 999                                           31.516996
# 1000                                          18.656996
#
#       emission_co2e_subsector_total_last_five_years_frst  \
# 0                                           -104.203459
# 1                                            -90.765169
# 2                                           -105.394860
# 3                                            -98.697311
# 4                                           -117.495744
# ...                                                 ...
# 996                                         -142.984360
# 997                                         -142.337871
# 998                                          -93.716664
# 999                                         -123.735413
# 1000                                        -138.098867
#
#       emission_co2e_subsector_total_last_five_years_inen  \
# 0                                              6.278755
# 1                                             32.437006
# 2                                             37.959592
# 3                                             19.116132
# 4                                             48.859457
# ...                                                 ...
# 996                                           22.202444
# 997                                           29.493983
# 998                                           25.704045
# 999                                           62.639449
# 1000                                          56.672494
#
#       emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                            105.479301
# 1                                            170.411122
# 2                                            160.811434
# 3                                            278.256437
# 4                                            336.430495
# ...                                                 ...
# 996                                          286.445998
# 997                                          279.742342
# 998                                          151.456788
# 999                                          431.668604
# 1000                                         222.316152
#
#       emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                             25.920040
# 1                                             49.462783
# 2                                             38.170739
# 3                                             36.429337
# 4                                             28.664949
# ...                                                 ...
# 996                                           36.106518
# 997                                           36.952759
# 998                                           50.791095
# 999                                           39.867251
# 1000                                          38.191907
#
#       emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                              0.587402
# 1                                              0.906453
# 2                                              0.970521
# 3                                              1.228347
# 4                                              1.090020
# ...                                                 ...
# 996                                            0.904249
# 997                                            1.216428
# 998                                            1.058287
# 999                                            1.146690
# 1000                                           1.308690
#
#       emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                              3.233606
# 1                                              3.535574
# 2                                              4.244111
# 3                                              4.422138
# 4                                              3.910358
# ...                                                 ...
# 996                                            5.081968
# 997                                            4.298082
# 998                                            5.626901
# 999                                            5.077615
# 1000                                           5.570105
#
#       emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                              1.718910
# 1                                              8.152285
# 2                                              8.154926
# 3                                             18.414907
# 4                                             13.270447
# ...                                                 ...
# 996                                           18.862049
# 997                                           21.376994
# 998                                            8.124589
# 999                                           20.556177
# 1000                                          20.212564
#
#       emission_co2e_subsector_total_last_five_years_soil  \
# 0                                             61.059653
# 1                                             89.352384
# 2                                             81.322226
# 3                                             76.882749
# 4                                             70.415909
# ...                                                 ...
# 996                                           71.560854
# 997                                           71.529692
# 998                                           78.423711
# 999                                           75.768872
# 1000                                          69.930832
#
#       emission_co2e_subsector_total_last_five_years_trns  \
# 0                                             85.252196
# 1                                            138.564932
# 2                                            156.911769
# 3                                            121.007564
# 4                                            121.967384
# ...                                                 ...
# 996                                          148.939474
# 997                                          218.459721
# 998                                          177.895404
# 999                                          184.266983
# 1000                                         192.199457
#
#       emission_co2e_subsector_total_last_five_years_trww  \
# 0                                              3.549219
# 1                                              4.811716
# 2                                              8.015643
# 3                                              4.921821
# 4                                              6.411074
# ...                                                 ...
# 996                                            5.825388
# 997                                            6.512837
# 998                                            9.338142
# 999                                            5.892799
# 1000                                           7.534391
#
#       emission_co2e_subsector_total_last_five_years_waso
# 0                                              4.419889
# 1                                             12.035590
# 2                                              5.746137
# 3                                              5.133122
# 4                                              8.231365
# ...                                                 ...
# 996                                            9.483685
# 997                                           12.824772
# 998                                            9.907313
# 999                                            5.865194
# 1000                                           6.728552
#
# [1001 rows x 18 columns]

# %% [markdown]
# ## Merge emissions data with lhs samples

# %%
attr_primary_df = pd.read_csv(os.path.join(SIMULATION_DIR_PATH, "ATTRIBUTE_PRIMARY.csv"))
attr_primary_df
# Out:
#       primary_id  design_id  strategy_id  future_id
# 0         275275          3         6002          0
# 1         275276          3         6002          1
# 2         275277          3         6002          2
# 3         275278          3         6002          3
# 4         275279          3         6002          4
# ...          ...        ...          ...        ...
# 996       276271          3         6002        996
# 997       276272          3         6002        997
# 998       276273          3         6002        998
# 999       276274          3         6002        999
# 1000      276275          3         6002       1000
#
# [1001 rows x 4 columns]

# %%
la_emissions_df_w_future_id = la_emissions_df_agg.merge(attr_primary_df, on="primary_id", how="inner")

# Drop design_id and stratgy_id columns
la_emissions_df_w_future_id = la_emissions_df_w_future_id.drop(columns=["design_id", "strategy_id", "time_period"])
la_emissions_df_w_future_id
# Out:
#       primary_id  total_emissions_last_five_years  \
# 0         275275                       140.265338
# 1         275276                       670.507643
# 2         275277                       604.450538
# 3         275278                       475.708631
# 4         275279                       758.004335
# ...          ...                              ...
# 996       276271                       623.338641
# 997       276272                       747.358673
# 998       276273                       634.154137
# 999       276274                       915.717778
# 1000      276275                       675.086427
#
#       emission_co2e_subsector_total_last_five_years_agrc  \
# 0                                              7.267550
# 1                                              8.061759
# 2                                              7.858164
# 3                                              8.307819
# 4                                              8.405054
# ...                                                 ...
# 996                                            7.691330
# 997                                            8.862801
# 998                                            6.485737
# 999                                            6.846038
# 1000                                           8.153176
#
#       emission_co2e_subsector_total_last_five_years_ccsq  \
# 0                                           -141.930311
# 1                                           -141.366606
# 2                                            -14.533055
# 3                                           -129.785123
# 4                                            -71.502824
# ...                                                 ...
# 996                                          -71.971267
# 997                                         -127.413593
# 998                                         -123.391600
# 999                                          -37.048767
# 1000                                         -71.693475
#
#       emission_co2e_subsector_total_last_five_years_entc  \
# 0                                             76.687418
# 1                                            334.273021
# 2                                            191.759751
# 3                                            117.203083
# 4                                            264.993930
# ...                                                 ...
# 996                                          192.425095
# 997                                          272.882069
# 998                                          291.514723
# 999                                          205.389288
# 1000                                         237.403454
#
#       emission_co2e_subsector_total_last_five_years_fgtv  \
# 0                                              4.945170
# 1                                             50.634794
# 2                                             22.453442
# 3                                             12.867610
# 4                                             34.352460
# ...                                                 ...
# 996                                           32.765217
# 997                                           52.957656
# 998                                           34.935666
# 999                                           31.516996
# 1000                                          18.656996
#
#       emission_co2e_subsector_total_last_five_years_frst  \
# 0                                           -104.203459
# 1                                            -90.765169
# 2                                           -105.394860
# 3                                            -98.697311
# 4                                           -117.495744
# ...                                                 ...
# 996                                         -142.984360
# 997                                         -142.337871
# 998                                          -93.716664
# 999                                         -123.735413
# 1000                                        -138.098867
#
#       emission_co2e_subsector_total_last_five_years_inen  \
# 0                                              6.278755
# 1                                             32.437006
# 2                                             37.959592
# 3                                             19.116132
# 4                                             48.859457
# ...                                                 ...
# 996                                           22.202444
# 997                                           29.493983
# 998                                           25.704045
# 999                                           62.639449
# 1000                                          56.672494
#
#       emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                            105.479301
# 1                                            170.411122
# 2                                            160.811434
# 3                                            278.256437
# 4                                            336.430495
# ...                                                 ...
# 996                                          286.445998
# 997                                          279.742342
# 998                                          151.456788
# 999                                          431.668604
# 1000                                         222.316152
#
#       emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                             25.920040
# 1                                             49.462783
# 2                                             38.170739
# 3                                             36.429337
# 4                                             28.664949
# ...                                                 ...
# 996                                           36.106518
# 997                                           36.952759
# 998                                           50.791095
# 999                                           39.867251
# 1000                                          38.191907
#
#       emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                              0.587402
# 1                                              0.906453
# 2                                              0.970521
# 3                                              1.228347
# 4                                              1.090020
# ...                                                 ...
# 996                                            0.904249
# 997                                            1.216428
# 998                                            1.058287
# 999                                            1.146690
# 1000                                           1.308690
#
#       emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                              3.233606
# 1                                              3.535574
# 2                                              4.244111
# 3                                              4.422138
# 4                                              3.910358
# ...                                                 ...
# 996                                            5.081968
# 997                                            4.298082
# 998                                            5.626901
# 999                                            5.077615
# 1000                                           5.570105
#
#       emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                              1.718910
# 1                                              8.152285
# 2                                              8.154926
# 3                                             18.414907
# 4                                             13.270447
# ...                                                 ...
# 996                                           18.862049
# 997                                           21.376994
# 998                                            8.124589
# 999                                           20.556177
# 1000                                          20.212564
#
#       emission_co2e_subsector_total_last_five_years_soil  \
# 0                                             61.059653
# 1                                             89.352384
# 2                                             81.322226
# 3                                             76.882749
# 4                                             70.415909
# ...                                                 ...
# 996                                           71.560854
# 997                                           71.529692
# 998                                           78.423711
# 999                                           75.768872
# 1000                                          69.930832
#
#       emission_co2e_subsector_total_last_five_years_trns  \
# 0                                             85.252196
# 1                                            138.564932
# 2                                            156.911769
# 3                                            121.007564
# 4                                            121.967384
# ...                                                 ...
# 996                                          148.939474
# 997                                          218.459721
# 998                                          177.895404
# 999                                          184.266983
# 1000                                         192.199457
#
#       emission_co2e_subsector_total_last_five_years_trww  \
# 0                                              3.549219
# 1                                              4.811716
# 2                                              8.015643
# 3                                              4.921821
# 4                                              6.411074
# ...                                                 ...
# 996                                            5.825388
# 997                                            6.512837
# 998                                            9.338142
# 999                                            5.892799
# 1000                                           7.534391
#
#       emission_co2e_subsector_total_last_five_years_waso  future_id
# 0                                              4.419889           0
# 1                                             12.035590           1
# 2                                              5.746137           2
# 3                                              5.133122           3
# 4                                              8.231365           4
# ...                                                 ...         ...
# 996                                            9.483685         996
# 997                                           12.824772         997
# 998                                            9.907313         998
# 999                                            5.865194         999
# 1000                                           6.728552        1000
#
# [1001 rows x 18 columns]

# %%
merged_df = pd.merge(lhc_trials_df, la_emissions_df_w_future_id, on="future_id", how="inner")

# rearrange columns to have future_id and primary_id at the front
cols_order = ["future_id", "primary_id"] + [col for col in merged_df.columns if col not in ["future_id", "primary_id"]]
merged_df = merged_df[cols_order]
merged_df
# Out:
#      future_id  primary_id         1         2         3         4         5  \
# 0            1      275276  0.952436  0.360397  0.202990  0.995748  0.369859
# 1            2      275277  0.304955  0.204875  0.540658  0.800192  0.206396
# 2            3      275278  0.609262  0.366443  0.601808  0.916668  0.386475
# 3            4      275279  0.815313  0.487444  0.323954  0.634299  0.064625
# 4            5      275280  0.973878  0.842718  0.884382  0.483039  0.455502
# ..         ...         ...       ...       ...       ...       ...       ...
# 995        996      276271  0.218189  0.886941  0.569155  0.107766  0.955775
# 996        997      276272  0.510025  0.235856  0.847465  0.138888  0.182086
# 997        998      276273  0.276479  0.612911  0.642697  0.952037  0.176638
# 998        999      276274  0.600573  0.553323  0.306380  0.464389  0.834916
# 999       1000      276275  0.164542  0.057579  0.648085  0.210240  0.441924
#
#             6         7         8  ...  \
# 0    0.919920  0.478450  0.445798  ...
# 1    0.777352  0.805727  0.536048  ...
# 2    0.181162  0.138910  0.768925  ...
# 3    0.926815  0.633805  0.439346  ...
# 4    0.003343  0.571994  0.108021  ...
# ..        ...       ...       ...  ...
# 995  0.380014  0.569711  0.312233  ...
# 996  0.453749  0.242018  0.215693  ...
# 997  0.411246  0.169671  0.694365  ...
# 998  0.786519  0.717580  0.168263  ...
# 999  0.364614  0.031031  0.873487  ...
#
#      emission_co2e_subsector_total_last_five_years_inen  \
# 0                                            32.437006
# 1                                            37.959592
# 2                                            19.116132
# 3                                            48.859457
# 4                                            27.739520
# ..                                                 ...
# 995                                          22.202444
# 996                                          29.493983
# 997                                          25.704045
# 998                                          62.639449
# 999                                          56.672494
#
#      emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                           170.411122
# 1                                           160.811434
# 2                                           278.256437
# 3                                           336.430495
# 4                                           251.830128
# ..                                                 ...
# 995                                         286.445998
# 996                                         279.742342
# 997                                         151.456788
# 998                                         431.668604
# 999                                         222.316152
#
#      emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                            49.462783
# 1                                            38.170739
# 2                                            36.429337
# 3                                            28.664949
# 4                                            46.485526
# ..                                                 ...
# 995                                          36.106518
# 996                                          36.952759
# 997                                          50.791095
# 998                                          39.867251
# 999                                          38.191907
#
#      emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                             0.906453
# 1                                             0.970521
# 2                                             1.228347
# 3                                             1.090020
# 4                                             0.984459
# ..                                                 ...
# 995                                           0.904249
# 996                                           1.216428
# 997                                           1.058287
# 998                                           1.146690
# 999                                           1.308690
#
#      emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                             3.535574
# 1                                             4.244111
# 2                                             4.422138
# 3                                             3.910358
# 4                                             3.737274
# ..                                                 ...
# 995                                           5.081968
# 996                                           4.298082
# 997                                           5.626901
# 998                                           5.077615
# 999                                           5.570105
#
#      emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                             8.152285
# 1                                             8.154926
# 2                                            18.414907
# 3                                            13.270447
# 4                                            15.296131
# ..                                                 ...
# 995                                          18.862049
# 996                                          21.376994
# 997                                           8.124589
# 998                                          20.556177
# 999                                          20.212564
#
#      emission_co2e_subsector_total_last_five_years_soil  \
# 0                                            89.352384
# 1                                            81.322226
# 2                                            76.882749
# 3                                            70.415909
# 4                                            76.307252
# ..                                                 ...
# 995                                          71.560854
# 996                                          71.529692
# 997                                          78.423711
# 998                                          75.768872
# 999                                          69.930832
#
#      emission_co2e_subsector_total_last_five_years_trns  \
# 0                                           138.564932
# 1                                           156.911769
# 2                                           121.007564
# 3                                           121.967384
# 4                                           229.067385
# ..                                                 ...
# 995                                         148.939474
# 996                                         218.459721
# 997                                         177.895404
# 998                                         184.266983
# 999                                         192.199457
#
#      emission_co2e_subsector_total_last_five_years_trww  \
# 0                                             4.811716
# 1                                             8.015643
# 2                                             4.921821
# 3                                             6.411074
# 4                                             7.548845
# ..                                                 ...
# 995                                           5.825388
# 996                                           6.512837
# 997                                           9.338142
# 998                                           5.892799
# 999                                           7.534391
#
#      emission_co2e_subsector_total_last_five_years_waso
# 0                                            12.035590
# 1                                             5.746137
# 2                                             5.133122
# 3                                             8.231365
# 4                                            10.952978
# ..                                                 ...
# 995                                           9.483685
# 996                                          12.824772
# 997                                           9.907313
# 998                                           5.865194
# 999                                           6.728552
#
# [1000 rows x 102 columns]

# %%
var_traj_df = pd.read_csv(os.path.join(MAPPING_DIR_PATH, "var_trajgroups_experiment.csv"))
var_traj_df.tail(10)
# Out:
#     variable_trajectory_group
# 37                         38
# 38                         39
# 39                         40
# 40                         41
# 41                         42
# 42                         43
# 43                         44
# 44                         45
# 45                         46
# 46                         47

# %%
# Convert the variable_trajectory_group column to list of strings
relevant_lhs_cols = var_traj_df["variable_trajectory_group"].values
relevant_lhs_cols = [str(col) for col in relevant_lhs_cols.tolist()]
# relevant_lhs_cols

# %%
df_cols = merged_df.columns.tolist()

# Filter the relevant_lhs_cols to only include those that are in df_cols
relevant_lhs_cols = [col for col in relevant_lhs_cols if col in df_cols]

# %%
# filter merged_df to keep only relevant columns
cols_to_keep = ["future_id", "primary_id"] + list(relevant_lhs_cols) + ["total_emissions_last_five_years"] + [col for col in merged_df.columns if col.startswith("emission_co2e_subsector_total")]
merged_df_filtered = merged_df[cols_to_keep]

# %%
merged_df_filtered
# Out:
#      future_id  primary_id         1         2         3         4         5  \
# 0            1      275276  0.952436  0.360397  0.202990  0.995748  0.369859
# 1            2      275277  0.304955  0.204875  0.540658  0.800192  0.206396
# 2            3      275278  0.609262  0.366443  0.601808  0.916668  0.386475
# 3            4      275279  0.815313  0.487444  0.323954  0.634299  0.064625
# 4            5      275280  0.973878  0.842718  0.884382  0.483039  0.455502
# ..         ...         ...       ...       ...       ...       ...       ...
# 995        996      276271  0.218189  0.886941  0.569155  0.107766  0.955775
# 996        997      276272  0.510025  0.235856  0.847465  0.138888  0.182086
# 997        998      276273  0.276479  0.612911  0.642697  0.952037  0.176638
# 998        999      276274  0.600573  0.553323  0.306380  0.464389  0.834916
# 999       1000      276275  0.164542  0.057579  0.648085  0.210240  0.441924
#
#             6         7         8  ...  \
# 0    0.919920  0.478450  0.445798  ...
# 1    0.777352  0.805727  0.536048  ...
# 2    0.181162  0.138910  0.768925  ...
# 3    0.926815  0.633805  0.439346  ...
# 4    0.003343  0.571994  0.108021  ...
# ..        ...       ...       ...  ...
# 995  0.380014  0.569711  0.312233  ...
# 996  0.453749  0.242018  0.215693  ...
# 997  0.411246  0.169671  0.694365  ...
# 998  0.786519  0.717580  0.168263  ...
# 999  0.364614  0.031031  0.873487  ...
#
#      emission_co2e_subsector_total_last_five_years_inen  \
# 0                                            32.437006
# 1                                            37.959592
# 2                                            19.116132
# 3                                            48.859457
# 4                                            27.739520
# ..                                                 ...
# 995                                          22.202444
# 996                                          29.493983
# 997                                          25.704045
# 998                                          62.639449
# 999                                          56.672494
#
#      emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                           170.411122
# 1                                           160.811434
# 2                                           278.256437
# 3                                           336.430495
# 4                                           251.830128
# ..                                                 ...
# 995                                         286.445998
# 996                                         279.742342
# 997                                         151.456788
# 998                                         431.668604
# 999                                         222.316152
#
#      emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                            49.462783
# 1                                            38.170739
# 2                                            36.429337
# 3                                            28.664949
# 4                                            46.485526
# ..                                                 ...
# 995                                          36.106518
# 996                                          36.952759
# 997                                          50.791095
# 998                                          39.867251
# 999                                          38.191907
#
#      emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                             0.906453
# 1                                             0.970521
# 2                                             1.228347
# 3                                             1.090020
# 4                                             0.984459
# ..                                                 ...
# 995                                           0.904249
# 996                                           1.216428
# 997                                           1.058287
# 998                                           1.146690
# 999                                           1.308690
#
#      emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                             3.535574
# 1                                             4.244111
# 2                                             4.422138
# 3                                             3.910358
# 4                                             3.737274
# ..                                                 ...
# 995                                           5.081968
# 996                                           4.298082
# 997                                           5.626901
# 998                                           5.077615
# 999                                           5.570105
#
#      emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                             8.152285
# 1                                             8.154926
# 2                                            18.414907
# 3                                            13.270447
# 4                                            15.296131
# ..                                                 ...
# 995                                          18.862049
# 996                                          21.376994
# 997                                           8.124589
# 998                                          20.556177
# 999                                          20.212564
#
#      emission_co2e_subsector_total_last_five_years_soil  \
# 0                                            89.352384
# 1                                            81.322226
# 2                                            76.882749
# 3                                            70.415909
# 4                                            76.307252
# ..                                                 ...
# 995                                          71.560854
# 996                                          71.529692
# 997                                          78.423711
# 998                                          75.768872
# 999                                          69.930832
#
#      emission_co2e_subsector_total_last_five_years_trns  \
# 0                                           138.564932
# 1                                           156.911769
# 2                                           121.007564
# 3                                           121.967384
# 4                                           229.067385
# ..                                                 ...
# 995                                         148.939474
# 996                                         218.459721
# 997                                         177.895404
# 998                                         184.266983
# 999                                         192.199457
#
#      emission_co2e_subsector_total_last_five_years_trww  \
# 0                                             4.811716
# 1                                             8.015643
# 2                                             4.921821
# 3                                             6.411074
# 4                                             7.548845
# ..                                                 ...
# 995                                           5.825388
# 996                                           6.512837
# 997                                           9.338142
# 998                                           5.892799
# 999                                           7.534391
#
#      emission_co2e_subsector_total_last_five_years_waso
# 0                                            12.035590
# 1                                             5.746137
# 2                                             5.133122
# 3                                             8.231365
# 4                                            10.952978
# ..                                                 ...
# 995                                           9.483685
# 996                                          12.824772
# 997                                           9.907313
# 998                                           5.865194
# 999                                           6.728552
#
# [1000 rows x 64 columns]

# %%
var_specifications_df = pd.read_csv(os.path.join(MAPPING_DIR_PATH, "variable_specification_to_sample_group.csv"))
# Filter var_specifications_df by sample_group in relevant_lhs_cols
relevant_lhs_cols = [int(col) for col in relevant_lhs_cols]
var_specifications_df = var_specifications_df[var_specifications_df["sample_group"].isin(relevant_lhs_cols)]
var_specifications_df = var_specifications_df.sort_values(by="sample_group", ascending=True)

# %%
def process_variable_prefix(df):
    result = []
    for group, group_df in df.groupby('sample_group'):
        variables = group_df['variable_specification'].tolist()
        if len(variables) == 1:
            prefix = variables[0]
        else:
            prefix = os.path.commonprefix(variables)
            # Clean trailing underscores
            prefix = prefix.rstrip('_')
            
        prefix = f"group_{group}_{prefix}"
        result.append({'sample_group': group, 'variable_prefix': prefix})
    return pd.DataFrame(result)

prefix_df = process_variable_prefix(var_specifications_df)
prefix_df
# Out:
#     sample_group                                    variable_prefix
# 0              1                            group_1_ef_lvst_entferm
# 1              2                                    group_2_yf_agrc
# 2              3                             group_3_demscalar_soil
# 3              4                             group_4_demscalar_ippu
# 4              5    group_5_efficfactor_enfu_industrial_energy_fuel
# 5              6                    group_6_elecfuelefficiency_trns
# 6              7   group_7_factor_waso_waste_per_capita_scalar_food
# 7              8                                  group_8_frac_fgtv
# 8              9      group_9_frac_agrc_agriculture_production_lost
# 9             10                                 group_10_frac_agrc
# 10            12  group_12_frac_enfu_transmission_loss_fuel_elec...
# 11            13                                          group_13_
# 12            14                  group_14_frac_ippu_cement_clinker
# 13            15     group_15_frac_ippu_production_with_co2_capture
# 14            16                              group_16_frac_lvst_mm
# 15            17                         group_17_frac_trns_fuelmix
# 16            18                group_18_frac_trns_mtkm_dem_freight
# 17            19                         group_19_frac_trns_pkm_dem
# 18            20                              group_20_frac_wali_ww
# 19            21                    group_21_frac_waso_non_recycled
# 20            22                                 group_22_frac_waso
# 21            23                        group_23_frac_waso_recycled
# 22            24                                 group_24_frac_waso
# 23            25                          group_25_frac_inen_energy
# 24            26                          group_26_frac_inen_energy
# 25            27                     group_27_frac_scoe_heat_energy
# 26            28                       group_28_fuelefficiency_trns
# 27            29                                     group_29_gasrf
# 28            30                             group_30_ef_ippu_tonne
# 29            31                     group_31_ef_ippu_tonne_n2o_per
# 30            32                  group_32_lndu_reallocation_factor
# 31            33                              group_33_exports_lvst
# 32            34                                group_34_nemomod_en
# 33            35  group_35_occrate_trns_passenger_per_vehicle_ro...
# 34            36                     group_36_pij_lndu_croplands_to
# 35            37             group_37_pij_lndu_forests_mangroves_to
# 36            38               group_38_pij_lndu_forests_primary_to
# 37            39             group_39_pij_lndu_forests_secondary_to
# 38            40                                          group_40_
# 39            41                         group_41_pij_lndu_other_to
# 40            42                   group_42_pij_lndu_settlements_to
# 41            43                      group_43_pij_lndu_wetlands_to
# 42            44       group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha
# 43            45             group_45_scalar_lvst_carrying_capacity
# 44            46       group_46_scalar_scoe_appliance_energy_demand
# 45            47            group_47_scalar_scoe_heat_energy_demand

# %%
var_specifications_df[var_specifications_df["sample_group"].isin([13, 40])]
# Out:
#                            variable_specification  sample_group
# 560   elasticity_agrc_sugar_cane_demand_to_income            13
# 876                     frac_gnrl_eating_red_meat            13
# 1177      frac_lndu_proportion_grasslands_pasture            40
# 2020       pij_lndu_grasslands_to_forests_primary            40
# 2021     pij_lndu_grasslands_to_forests_secondary            40
# 2022            pij_lndu_grasslands_to_grasslands            40
# 2024           pij_lndu_grasslands_to_settlements            40
# 2025              pij_lndu_grasslands_to_wetlands            40
# 2023                 pij_lndu_grasslands_to_other            40
# 2019     pij_lndu_grasslands_to_forests_mangroves            40
# 2018             pij_lndu_grasslands_to_croplands            40

# %%
prefix_df.loc[prefix_df["sample_group"] == 13, "variable_prefix"] = "group_13_frac_gnrl_eating_red_meats+"
prefix_df.loc[prefix_df["sample_group"] == 40, "variable_prefix"] = "group_40_pij_lndu_grasslands+"

prefix_df = prefix_df.sort_values(by="variable_prefix", ascending=True)
prefix_df
# Out:
#     sample_group                                    variable_prefix
# 9             10                                 group_10_frac_agrc
# 10            12  group_12_frac_enfu_transmission_loss_fuel_elec...
# 11            13               group_13_frac_gnrl_eating_red_meats+
# 12            14                  group_14_frac_ippu_cement_clinker
# 13            15     group_15_frac_ippu_production_with_co2_capture
# 14            16                              group_16_frac_lvst_mm
# 15            17                         group_17_frac_trns_fuelmix
# 16            18                group_18_frac_trns_mtkm_dem_freight
# 17            19                         group_19_frac_trns_pkm_dem
# 0              1                            group_1_ef_lvst_entferm
# 18            20                              group_20_frac_wali_ww
# 19            21                    group_21_frac_waso_non_recycled
# 20            22                                 group_22_frac_waso
# 21            23                        group_23_frac_waso_recycled
# 22            24                                 group_24_frac_waso
# 23            25                          group_25_frac_inen_energy
# 24            26                          group_26_frac_inen_energy
# 25            27                     group_27_frac_scoe_heat_energy
# 26            28                       group_28_fuelefficiency_trns
# 27            29                                     group_29_gasrf
# 1              2                                    group_2_yf_agrc
# 28            30                             group_30_ef_ippu_tonne
# 29            31                     group_31_ef_ippu_tonne_n2o_per
# 30            32                  group_32_lndu_reallocation_factor
# 31            33                              group_33_exports_lvst
# 32            34                                group_34_nemomod_en
# 33            35  group_35_occrate_trns_passenger_per_vehicle_ro...
# 34            36                     group_36_pij_lndu_croplands_to
# 35            37             group_37_pij_lndu_forests_mangroves_to
# 36            38               group_38_pij_lndu_forests_primary_to
# 37            39             group_39_pij_lndu_forests_secondary_to
# 2              3                             group_3_demscalar_soil
# 38            40                      group_40_pij_lndu_grasslands+
# 39            41                         group_41_pij_lndu_other_to
# 40            42                   group_42_pij_lndu_settlements_to
# 41            43                      group_43_pij_lndu_wetlands_to
# 42            44       group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha
# 43            45             group_45_scalar_lvst_carrying_capacity
# 44            46       group_46_scalar_scoe_appliance_energy_demand
# 45            47            group_47_scalar_scoe_heat_energy_demand
# 3              4                             group_4_demscalar_ippu
# 4              5    group_5_efficfactor_enfu_industrial_energy_fuel
# 5              6                    group_6_elecfuelefficiency_trns
# 6              7   group_7_factor_waso_waste_per_capita_scalar_food
# 7              8                                  group_8_frac_fgtv
# 8              9      group_9_frac_agrc_agriculture_production_lost

# %%
# Let's use the prefix_df to rename the columns in merged_df_filtered
def rename_columns_with_prefix(merged_df, prefix_df):
    df = merged_df.copy()
    for _, row in prefix_df.iterrows():
        sample_group = row['sample_group']
        variable_prefix = row['variable_prefix']
        cols_to_rename = [col for col in df.columns if col.startswith(str(sample_group))]
        for col in cols_to_rename:
            new_col_name = f"{variable_prefix}"
            df = df.rename(columns={col: new_col_name})
    return df
merged_df_filtered_w_prefix = rename_columns_with_prefix(merged_df_filtered, prefix_df)

# %%
merged_df_filtered_w_prefix
# Out:
#      future_id  primary_id  group_1_ef_lvst_entferm  group_2_yf_agrc  \
# 0            1      275276                 0.952436         0.360397
# 1            2      275277                 0.304955         0.204875
# 2            3      275278                 0.609262         0.366443
# 3            4      275279                 0.815313         0.487444
# 4            5      275280                 0.973878         0.842718
# ..         ...         ...                      ...              ...
# 995        996      276271                 0.218189         0.886941
# 996        997      276272                 0.510025         0.235856
# 997        998      276273                 0.276479         0.612911
# 998        999      276274                 0.600573         0.553323
# 999       1000      276275                 0.164542         0.057579
#
#      group_3_demscalar_soil  group_4_demscalar_ippu  \
# 0                  0.202990                0.995748
# 1                  0.540658                0.800192
# 2                  0.601808                0.916668
# 3                  0.323954                0.634299
# 4                  0.884382                0.483039
# ..                      ...                     ...
# 995                0.569155                0.107766
# 996                0.847465                0.138888
# 997                0.642697                0.952037
# 998                0.306380                0.464389
# 999                0.648085                0.210240
#
#      group_5_efficfactor_enfu_industrial_energy_fuel  \
# 0                                           0.369859
# 1                                           0.206396
# 2                                           0.386475
# 3                                           0.064625
# 4                                           0.455502
# ..                                               ...
# 995                                         0.955775
# 996                                         0.182086
# 997                                         0.176638
# 998                                         0.834916
# 999                                         0.441924
#
#      group_6_elecfuelefficiency_trns  \
# 0                           0.919920
# 1                           0.777352
# 2                           0.181162
# 3                           0.926815
# 4                           0.003343
# ..                               ...
# 995                         0.380014
# 996                         0.453749
# 997                         0.411246
# 998                         0.786519
# 999                         0.364614
#
#      group_7_factor_waso_waste_per_capita_scalar_food  group_8_frac_fgtv  ...  \
# 0                                            0.478450           0.445798  ...
# 1                                            0.805727           0.536048  ...
# 2                                            0.138910           0.768925  ...
# 3                                            0.633805           0.439346  ...
# 4                                            0.571994           0.108021  ...
# ..                                                ...                ...  ...
# 995                                          0.569711           0.312233  ...
# 996                                          0.242018           0.215693  ...
# 997                                          0.169671           0.694365  ...
# 998                                          0.717580           0.168263  ...
# 999                                          0.031031           0.873487  ...
#
#      emission_co2e_subsector_total_last_five_years_inen  \
# 0                                            32.437006
# 1                                            37.959592
# 2                                            19.116132
# 3                                            48.859457
# 4                                            27.739520
# ..                                                 ...
# 995                                          22.202444
# 996                                          29.493983
# 997                                          25.704045
# 998                                          62.639449
# 999                                          56.672494
#
#      emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                           170.411122
# 1                                           160.811434
# 2                                           278.256437
# 3                                           336.430495
# 4                                           251.830128
# ..                                                 ...
# 995                                         286.445998
# 996                                         279.742342
# 997                                         151.456788
# 998                                         431.668604
# 999                                         222.316152
#
#      emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                            49.462783
# 1                                            38.170739
# 2                                            36.429337
# 3                                            28.664949
# 4                                            46.485526
# ..                                                 ...
# 995                                          36.106518
# 996                                          36.952759
# 997                                          50.791095
# 998                                          39.867251
# 999                                          38.191907
#
#      emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                             0.906453
# 1                                             0.970521
# 2                                             1.228347
# 3                                             1.090020
# 4                                             0.984459
# ..                                                 ...
# 995                                           0.904249
# 996                                           1.216428
# 997                                           1.058287
# 998                                           1.146690
# 999                                           1.308690
#
#      emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                             3.535574
# 1                                             4.244111
# 2                                             4.422138
# 3                                             3.910358
# 4                                             3.737274
# ..                                                 ...
# 995                                           5.081968
# 996                                           4.298082
# 997                                           5.626901
# 998                                           5.077615
# 999                                           5.570105
#
#      emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                             8.152285
# 1                                             8.154926
# 2                                            18.414907
# 3                                            13.270447
# 4                                            15.296131
# ..                                                 ...
# 995                                          18.862049
# 996                                          21.376994
# 997                                           8.124589
# 998                                          20.556177
# 999                                          20.212564
#
#      emission_co2e_subsector_total_last_five_years_soil  \
# 0                                            89.352384
# 1                                            81.322226
# 2                                            76.882749
# 3                                            70.415909
# 4                                            76.307252
# ..                                                 ...
# 995                                          71.560854
# 996                                          71.529692
# 997                                          78.423711
# 998                                          75.768872
# 999                                          69.930832
#
#      emission_co2e_subsector_total_last_five_years_trns  \
# 0                                           138.564932
# 1                                           156.911769
# 2                                           121.007564
# 3                                           121.967384
# 4                                           229.067385
# ..                                                 ...
# 995                                         148.939474
# 996                                         218.459721
# 997                                         177.895404
# 998                                         184.266983
# 999                                         192.199457
#
#      emission_co2e_subsector_total_last_five_years_trww  \
# 0                                             4.811716
# 1                                             8.015643
# 2                                             4.921821
# 3                                             6.411074
# 4                                             7.548845
# ..                                                 ...
# 995                                           5.825388
# 996                                           6.512837
# 997                                           9.338142
# 998                                           5.892799
# 999                                           7.534391
#
#      emission_co2e_subsector_total_last_five_years_waso
# 0                                            12.035590
# 1                                             5.746137
# 2                                             5.133122
# 3                                             8.231365
# 4                                            10.952978
# ..                                                 ...
# 995                                           9.483685
# 996                                          12.824772
# 997                                           9.907313
# 998                                           5.865194
# 999                                           6.728552
#
# [1000 rows x 64 columns]

# %%
#save the merged DataFrame to a CSV file
merged_df_filtered_w_prefix.to_csv(os.path.join(TRAINING_DIR_PATH, "training_data.csv"), index=False)
